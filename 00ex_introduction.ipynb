# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. For numbers which are multiples of both three and five print MickeyMouse
#
# b) Put the result in a tuple and substitute Mickey with Donald and Mouse with Duck

# %%
variables=[*range(0,100)]
for i in variables:
    if variables[i]%3==0:
        print("Mickey")
        variables[i]="Mickey"
    else: 
        if variables[i]%5==0:
            print("Mickey Mouse")
            variables[i]="Mickey Mouse"
        else:
            print(variables[i])
print(variables)
tup=tuple(variables)
#tuples are immutable, so I used a list to get the elements and then send them to a tuple
# Out:
# Mickey
# 1
# 2
# Mickey
# 4
# Mickey Mouse
# Mickey
# 7
# 8
# Mickey
# Mickey Mouse
# 11
# Mickey
# 13
# 14
# Mickey
# 16
# 17
# Mickey
# 19
# Mickey Mouse
# Mickey
# 22
# 23
# Mickey
# Mickey Mouse
# 26
# Mickey
# 28
# 29
# Mickey
# 31
# 32
# Mickey
# 34
# Mickey Mouse
# Mickey
# 37
# 38
# Mickey
# Mickey Mouse
# 41
# Mickey
# 43
# 44
# Mickey
# 46
# 47
# Mickey
# 49
# Mickey Mouse
# Mickey
# 52
# 53
# Mickey
# Mickey Mouse
# 56
# Mickey
# 58
# 59
# Mickey
# 61
# 62
# Mickey
# 64
# Mickey Mouse
# Mickey
# 67
# 68
# Mickey
# Mickey Mouse
# 71
# Mickey
# 73
# 74
# Mickey
# 76
# 77
# Mickey
# 79
# Mickey Mouse
# Mickey
# 82
# 83
# Mickey
# Mickey Mouse
# 86
# Mickey
# 88
# 89
# Mickey
# 91
# 92
# Mickey
# 94
# Mickey Mouse
# Mickey
# 97
# 98
# Mickey
# ...

# %% [markdown]
# 2\. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
def swap(x,y,):
    list=[y,x]
    return list
primo=input("type a variable: ")
secondo=input("type another variable: ")
lista=swap(primo, secondo)
x=lista[0]
y=lista[1]
print("the swaped set is:", lista[0],lista[1])

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
print("first point:\n")
punto1x=int(input("type the coordinate x: "))
punto1y=int(input("type the coordinate y: "))
u=(punto1x,punto1y)
print("\nsecond point:\n")
punto2x=int(input("type the coordinate x: "))
punto2y=int(input("type the coordinate y: "))
v=(punto2x,punto2y)
def distance(u,v):
    import math
    aux1=(u[0]-v[0])**2
    print(aux1)
    aux2=(u[1]-v[1])**2
    print(aux2)
    distance=math.sqrt(aux1+aux2)
    return distance
print(distance(u,v))
# Out:
# first point:
#
# type the coordinate x: 0
# type the coordinate y: 0
#
# second point:
#
# type the coordinate x: 4
# type the coordinate y: 5
# 16
# 25
# 6.4031242374328485

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
string="this is a given string"
lista=list(string)
tabella=[]
for i in lista:
    aux=0
    for u in lista:
        if u==i:
         aux=aux+1
    print("the character ", i, "apears ",aux," times"   )
# Out:
# the character  t apears  2  times
# the character  h apears  1  times
# the character  i apears  4  times
# the character  s apears  3  times
# the character    apears  4  times
# the character  i apears  4  times
# the character  s apears  3  times
# the character    apears  4  times
# the character  a apears  1  times
# the character    apears  4  times
# the character  g apears  2  times
# the character  i apears  4  times
# the character  v apears  1  times
# the character  e apears  1  times
# the character  n apears  2  times
# the character    apears  4  times
# the character  s apears  3  times
# the character  t apears  2  times
# the character  r apears  1  times
# the character  i apears  4  times
# the character  n apears  2  times
# the character  g apears  2  times

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]
def unique(list):
    cont=0
    for i in list:
        aux=0
        for v in list:
            if v==i:
                 aux=aux+1
        if aux==1:
            cont=cont+1
            print(i, " is a unique number")
    return cont
answer=unique(l)
print("the number of uniques is: ", answer)
# Out:
# 58  is a unique number
# 74  is a unique number
# 96  is a unique number
# 64  is a unique number
# 10  is a unique number
# 24  is a unique number
# 19  is a unique number
# 33  is a unique number
# 86  is a unique number
# 99  is a unique number
# 18  is a unique number
# 47  is a unique number
# 88  is a unique number
# 55  is a unique number
# 54  is a unique number
# 8  is a unique number
# 79  is a unique number
# 81  is a unique number
# 57  is a unique number
# 37  is a unique number
# 1  is a unique number
# 9  is a unique number
# 95  is a unique number
# 90  is a unique number
# 98  is a unique number
# 39  is a unique number
# 16  is a unique number
# 82  is a unique number
# 92  is a unique number
# 41  is a unique number
# 30  is a unique number
# 94  is a unique number
# 5  is a unique number
# 72  is a unique number
# 87  is a unique number
# 75  is a unique number
# 53  is a unique number
# the number of uniques is:  37

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def square(x):
    return x*x
def cube(y):
    return y*y*y
def sixth(w):
    sixth=square(w)*cube(w)
    return sixth
print(sixth(2))
# Out:
# 32

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
rand=[]
for i in range(0,11):
    rand.append(i*i*i)
print(rand)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
randomvariable=[]
for i in range(1,100):
    for j in range(1,100):
        for w in range(1,100):
            if i*i+j*j==w*w:
                print("a triple:", i, j , w)
                tripple=[i,j,w]
                randomvariable.append(tripple)
def convert(lista):
    return tuple(lista)
print(convert(randomvariable))
# Out:
# a triple: 3 4 5
# a triple: 4 3 5
# a triple: 5 12 13
# a triple: 6 8 10
# a triple: 7 24 25
# a triple: 8 6 10
# a triple: 8 15 17
# a triple: 9 12 15
# a triple: 9 40 41
# a triple: 10 24 26
# a triple: 11 60 61
# a triple: 12 5 13
# a triple: 12 9 15
# a triple: 12 16 20
# a triple: 12 35 37
# a triple: 13 84 85
# a triple: 14 48 50
# a triple: 15 8 17
# a triple: 15 20 25
# a triple: 15 36 39
# a triple: 16 12 20
# a triple: 16 30 34
# a triple: 16 63 65
# a triple: 18 24 30
# a triple: 18 80 82
# a triple: 20 15 25
# a triple: 20 21 29
# a triple: 20 48 52
# a triple: 21 20 29
# a triple: 21 28 35
# a triple: 21 72 75
# a triple: 24 7 25
# a triple: 24 10 26
# a triple: 24 18 30
# a triple: 24 32 40
# a triple: 24 45 51
# a triple: 24 70 74
# a triple: 25 60 65
# a triple: 27 36 45
# a triple: 28 21 35
# a triple: 28 45 53
# a triple: 30 16 34
# a triple: 30 40 50
# a triple: 30 72 78
# a triple: 32 24 40
# a triple: 32 60 68
# a triple: 33 44 55
# a triple: 33 56 65
# ...

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
def normalizer(numbers):
    lista=list(numbers)
    import math
    aux=0
    for i in lista:
        aux=i*i+aux
    denominator=math.sqrt(aux)
    for i in range(len(lista)):
        lista[i]=lista[i]/denominator   
    return lista
print(normalizer((1,2,5,6,7,7)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-08e2a7fb6dd5> in <module>
#       9         lista[i]=lista[i]/denominator
#      10     return lista
# ---> 11 print(normalizer((1,2,5,6,7,7)))
#
# <ipython-input-20-08e2a7fb6dd5> in normalizer(numbers)
#       1 def normalizer(numbers):
# ----> 2     lista=list(numbers)
#       3     import math
#       4     aux=0
#       5     for i in lista:
#
# TypeError: 'list' object is not callable

# %%
list
# Out:
# [[3, 4, 5],
#  [4, 3, 5],
#  [5, 12, 13],
#  [6, 8, 10],
#  [7, 24, 25],
#  [8, 6, 10],
#  [8, 15, 17],
#  [9, 12, 15],
#  [9, 40, 41],
#  [10, 24, 26],
#  [11, 60, 61],
#  [12, 5, 13],
#  [12, 9, 15],
#  [12, 16, 20],
#  [12, 35, 37],
#  [13, 84, 85],
#  [14, 48, 50],
#  [15, 8, 17],
#  [15, 20, 25],
#  [15, 36, 39],
#  [16, 12, 20],
#  [16, 30, 34],
#  [16, 63, 65],
#  [18, 24, 30],
#  [18, 80, 82],
#  [20, 15, 25],
#  [20, 21, 29],
#  [20, 48, 52],
#  [21, 20, 29],
#  [21, 28, 35],
#  [21, 72, 75],
#  [24, 7, 25],
#  [24, 10, 26],
#  [24, 18, 30],
#  [24, 32, 40],
#  [24, 45, 51],
#  [24, 70, 74],
#  [25, 60, 65],
#  [27, 36, 45],
#  [28, 21, 35],
#  [28, 45, 53],
#  [30, 16, 34],
#  [30, 40, 50],
#  [30, 72, 78],
#  [32, 24, 40],
#  [32, 60, 68],
#  [33, 44, 55],
#  [33, 56, 65],
#  [35, 12, 37],
#  [35, 84, 91],
#  [36, 15, 39],
#  [36, 27, 45],
#  [36, 48, 60],
#  [36, 77, 85],
#  [39, 52, 65],
#  [39, 80, 89],
#  [40, 9, 41],
#  [40, 30, 50],
#  [40, 42, 58],
#  [40, 75, 85],
# ...
