# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. For numbers which are multiples of both three and five print MickeyMouse
#
# b) Put the result in a tuple and substitute Mickey with Donald and Mouse with Duck

# %%
#Solution for a
results = []
for i in range(1,101): 
    if  (i%5 == 0 and i%3 == 0): 
        #print("Mickey Mouse")
        results.append("Mickey Mouse")
    elif (i%5 == 0): 
        #print("Mouse")
        results.append("Mouse")
    elif (i%3 == 0): 
        #print("Mickey")
        results.append("Mickey")
    else: 
        #print(i)
        results.append(i)
        
#Solution for b
results_tuple = tuple(results)

#I have placed the reult in a tupple but tupples cannot be altered
#so I am putting it back into a list to make the modifications

results_list = list(results_tuple)

for i in range(100):
    if (results_list[i] == "Mickey"): results_list[i] = "Donald"
    if (results_list[i] == "Mouse"): results_list[i] = "Duck"

results_tuple = tuple(results_list)

print (results_tuple)
# Out:
# (1, 2, 'Donald', 4, 'Duck', 'Donald', 7, 8, 'Donald', 'Duck', 11, 'Donald', 13, 14, 'Mickey Mouse', 16, 17, 'Donald', 19, 'Duck', 'Donald', 22, 23, 'Donald', 'Duck', 26, 'Donald', 28, 29, 'Mickey Mouse', 31, 32, 'Donald', 34, 'Duck', 'Donald', 37, 38, 'Donald', 'Duck', 41, 'Donald', 43, 44, 'Mickey Mouse', 46, 47, 'Donald', 49, 'Duck', 'Donald', 52, 53, 'Donald', 'Duck', 56, 'Donald', 58, 59, 'Mickey Mouse', 61, 62, 'Donald', 64, 'Duck', 'Donald', 67, 68, 'Donald', 'Duck', 71, 'Donald', 73, 74, 'Mickey Mouse', 76, 77, 'Donald', 79, 'Duck', 'Donald', 82, 83, 'Donald', 'Duck', 86, 'Donald', 88, 89, 'Mickey Mouse', 91, 92, 'Donald', 94, 'Duck', 'Donald', 97, 98, 'Donald', 'Duck')

# %% [markdown]
# 2\. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
def swap(a,b):
    return b,a

a = 1
b = 2

a,b = swap(a,b)

print(a,b)

a = "go"
b = "there"

a,b = swap(a,b)
print(a,b)
# Out:
# 2 1
# there go

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
def dist(u,v):
    a = abs(u[1]-v[1])
    b = abs(u[0]-v[0])
    h = (a**2+b**2)**(1/2)
    return h
    
u = (3,0)
v = (0,4)

print(dist(u,v))
# Out:
# 5.0

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

s = s.lower()
z = list(set(s))
dic = {}
for i in range(len(z)):
    c = s.count(z[i])
    dic[z[i]] = ['Occurs ', c,' times']
    
dic
# Out:
# {'b': ['Occurs ', 5, ' times'],
#  'f': ['Occurs ', 10, ' times'],
#  'i': ['Occurs ', 14, ' times'],
#  'h': ['Occurs ', 9, ' times'],
#  'g': ['Occurs ', 1, ' times'],
#  'w': ['Occurs ', 2, ' times'],
#  'n': ['Occurs ', 10, ' times'],
#  'k': ['Occurs ', 2, ' times'],
#  '.': ['Occurs ', 2, ' times'],
#  'c': ['Occurs ', 3, ' times'],
#  ' ': ['Occurs ', 41, ' times'],
#  't': ['Occurs ', 19, ' times'],
#  's': ['Occurs ', 9, ' times'],
#  'y': ['Occurs ', 2, ' times'],
#  'l': ['Occurs ', 6, ' times'],
#  'm': ['Occurs ', 12, ' times'],
#  'd': ['Occurs ', 3, ' times'],
#  'p': ['Occurs ', 8, ' times'],
#  'r': ['Occurs ', 17, ' times'],
#  '1': ['Occurs ', 2, ' times'],
#  'u': ['Occurs ', 9, ' times'],
#  'v': ['Occurs ', 2, ' times'],
#  'a': ['Occurs ', 7, ' times'],
#  '0': ['Occurs ', 2, ' times'],
#  'o': ['Occurs ', 13, ' times'],
#  'e': ['Occurs ', 22, ' times']}

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

def unicorn(l):
    l = set(l)
    count = len(l)
    print("The unique numbers are", l, "There are ",count, " of them.")
    
unicorn(l)
# Out:
# The unique numbers are {1, 3, 5, 8, 9, 10, 16, 18, 19, 20, 24, 30, 31, 33, 34, 36, 37, 39, 41, 42, 45, 47, 50, 51, 53, 54, 55, 56, 57, 58, 63, 64, 66, 70, 72, 74, 75, 79, 81, 82, 84, 85, 86, 87, 88, 89, 90, 91, 92, 94, 95, 96, 98, 99} There are  54  of them.

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def sq(a):
    return a**2
def cb(a):
    return a**3

def six(a):
    return cb(sq(a))

print(sq(2),cb(2),six(2))
# Out:
# 4 8 64

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
cubes1 = []
for x in range(11):
    cubes1.append(x**3)
print(cubes1)

cubes2 = [x**3 for x in range(11)]
print(cubes2)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
##For loop version
at = []
for a in range(1,101):
    for b in range(1,101):
        c = (a**2 + b**2)**(1/2)
        if (c%1==0): at.append([a,b,c])

##nested comprehension version
at2 = [[a,b,c] for a in range(1,101) for b in range(1,101) for c in range(1,101) if(a**2+b**2==c**2)]
at2 = tuple(at2)
print(at2)
# Out:
# ([3, 4, 5], [4, 3, 5], [5, 12, 13], [6, 8, 10], [7, 24, 25], [8, 6, 10], [8, 15, 17], [9, 12, 15], [9, 40, 41], [10, 24, 26], [11, 60, 61], [12, 5, 13], [12, 9, 15], [12, 16, 20], [12, 35, 37], [13, 84, 85], [14, 48, 50], [15, 8, 17], [15, 20, 25], [15, 36, 39], [16, 12, 20], [16, 30, 34], [16, 63, 65], [18, 24, 30], [18, 80, 82], [20, 15, 25], [20, 21, 29], [20, 48, 52], [21, 20, 29], [21, 28, 35], [21, 72, 75], [24, 7, 25], [24, 10, 26], [24, 18, 30], [24, 32, 40], [24, 45, 51], [24, 70, 74], [25, 60, 65], [27, 36, 45], [28, 21, 35], [28, 45, 53], [28, 96, 100], [30, 16, 34], [30, 40, 50], [30, 72, 78], [32, 24, 40], [32, 60, 68], [33, 44, 55], [33, 56, 65], [35, 12, 37], [35, 84, 91], [36, 15, 39], [36, 27, 45], [36, 48, 60], [36, 77, 85], [39, 52, 65], [39, 80, 89], [40, 9, 41], [40, 30, 50], [40, 42, 58], [40, 75, 85], [42, 40, 58], [42, 56, 70], [44, 33, 55], [45, 24, 51], [45, 28, 53], [45, 60, 75], [48, 14, 50], [48, 20, 52], [48, 36, 60], [48, 55, 73], [48, 64, 80], [51, 68,
# ...

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
def norm(t):
    tot = t[0]+t[1]+t[2]
    return (t[0]/tot, t[1]/tot, t[2]/tot)

test = norm((2,2,7))

print(test, sum(test))
# Out:
# (0.18181818181818182, 0.18181818181818182, 0.6363636363636364) 1.0
